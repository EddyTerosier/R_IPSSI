# %%
#Vecteurs :
#La fonction "c" comme combine !
#1. Quelle est l'équivalent de la fonction "c" dans Python pour augmenter/ajouter un élément dans un array (type numpy) éventuellement une liste ?
La fonction c permet de combiner et ou ajouter des éléments, dans Python c'est : liste = [1, 2, 3]
liste.append(4) et pour array : import numpy as np
arr = np.array([1, 2, 3])
arr = np.append(arr, 4)

# %% [markdown]
# 2. Créer un vecteur "v" qui comporte une séquence de 1 à 100  ? Rappeler comment créer un tuple ou une liste qui comporte une séquence de 1 à 100 en Python ?

# %%
v <- 1:100
#PYTHON : v = list(range(1, 101)) ou tuple : v = tuple(range(1, 101)).

# %% [markdown]
# Afficher la 1ère, la dernière valeur, les cinq 1ères, les 5 dernières valeurs, tout sauf les 5 dernières valeurs, tout sauf les 5 1ères et les 5 dernières valeurs de v ?

# %%
v[1]
# Indexation commence par 1

# %%
v[length(v)]
#Resultat 100 car derniere valeur

# %%
v[1:5]
#Séquencé : 1,2,3,4 et 5

# %%
v[(length(v)-4):length(v)]
#100-4 = 96 donc données : 96,97,98,99 et 100

# %%
v[-((length(v)-4):length(v))]
#Garde que les valeurs de 1 à 95

# %%
v[6:(length(v)-5)]
# garde les valeurs de 6 à 95.

# %% [markdown]
# 4. Extraire la 1ère, la 4ème et les 3 dernières valeurs de v ? Tout sauf la 1ère, la 4ème et les 3 dernières valeurs de v ? Extraire la 1ère et les 3 dernières valeurs mais sans la 4ème ?

# %%
c(v[1], v[4], v[(length(v)-2):length(v)])

# %%
v[-c(1, 4, (length(v)-2):length(v))]

# %%
c(v[1], v[(length(v)-2):length(v)])

# %% [markdown]
# 5. Décomposez le vecteur “v” en 2 vecteurs (v_pair et v_impair) où le 1èr contient les valeurs pairs et le 2ème les valeurs impairs ?

# %%
v_pair   <- v[v %% 2 == 0]
v_impair <- v[v %% 2 == 1]
# Out:
# Error: object 'v' not found
# Traceback:

# %% [markdown]
# 6. Créer le vecteur R : ("R", "R",...,"R", "R"). En d'autres termes, vous répétez "R" 20 fois ?

# %%
R <- rep("R", 20)
#REPETITION DE LA VALEUR R 20 fois

# %% [markdown]
# 7. Créer ce vecteur ("R", "R", "R", "R", "R", "0", "0.125", "0.25", "0.375", "0.5", "0.625", "0.75", "0.875", "1") ?

# %%
v7 <- c("R", "R", "R", "R", "R",
        "0", "0.125", "0.25", "0.375", "0.5",
        "0.625", "0.75", "0.875", "1")

# %% [markdown]
# 8. Créer ce vecteur ("Rouge", "Bleu", "Vert", "Rouge", "Bleu", "Vert", "Rouge", "Bleu", "Vert") ?

# %%
couleurs <- c("Rouge", "Bleu", "Vert",
              "Rouge", "Bleu", "Vert",
              "Rouge", "Bleu", "Vert")
#REPETITION DES MOTIFS 3 FOIS
